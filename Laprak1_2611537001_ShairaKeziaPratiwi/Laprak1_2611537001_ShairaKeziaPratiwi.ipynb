# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **PRAKTIKUM ALGORITMA DAN PEMOGRAMAN**
#
# **“PENGENALAN PYTHON VS CODE DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Shaira Kezia Pratiwi**
#
# **2611537001**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum pertemuan-1 (Pengenalan Python,VS code, dan koneksi ke Github) yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pengenalan aplikasi Python,VS code, dan koneksi ke Github.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung pembuatan code program menggunakan python di VS code,serta mengolah repositori proyek melalui Github.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemrograman merupakan salah satu kemampuan dasar yang penting dalam bidang Informatika karena dapat digunakan untuk menyelesaikan berbagai permasalahan secara sistematis. Python menjadi salah satu bahasa pemrograman yang digunakan untuk mempelajari konsep dasar algoritma dan pemrograman karena memiliki sintaks yang sederhana dan mudah dipahami.
#
# Dalam praktikum ini, mahasiswa mempelajari dasar penggunaan Python melalui Visual Studio Code (VS Code) serta penggunaan GitHub untuk menyimpan dan mengelola kode program. Praktikum ini diharapkan dapat membantu mahasiswa memahami dasar pemrograman sekaligus membiasakan penggunaan tools yang digunakan dalam pengembangan perangkat lunak.
#
# ## 1.2 Tujuan
# 1. Memahami dasar-dasar bahasa pemrograman Python.
# 2. Memahami penggunaan Visual Studio Code (VS Code) untuk menulis dan menjalankan program.
# 3. Memahami penggunaan GitHub untuk menyimpan dan mengelola kode program.
#
# ## 1.3 Manfaat
# 1. Meningkatkan pemahaman dan keterampilan dasar dalam pemrograman menggunakan Python.
# 2. Membiasakan penggunaan VS Code dan GitHub sebagai tools dalam pengembangan program.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# 1. Python adalah bahasa pemrograman tingkat tinggi yang bersifat sederhana dan mudah dipahami. Python banyak digunakan untuk membuat berbagai aplikasi, mengolah data, serta mempelajari konsep dasar algoritma dan pemrograman.
# 2. Visual Studio Code adalah aplikasi code editor yang digunakan untuk menulis, mengedit, dan menjalankan kode program. VS Code mendukung berbagai bahasa pemrograman, termasuk Python, serta menyediakan fitur yang membantu proses pengembangan program.
# 3. GitHub adalah platform berbasis internet yang digunakan untuk menyimpan, mengelola, dan berbagi kode program. GitHub juga menggunakan sistem version control yang membantu pengguna dalam mencatat dan mengelola perubahan pada kode.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "A_2611537001"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program pertama
"""
komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print ("hello world")
print ()
print ("print ini menghasilkan")
print("empat baris output")
print ("/ \\ // \\\\ /// \\\\\ " )
print ("program ini" + "dibuat oleh a\n" + "shaira 2611537001")

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama sampai keenam sebagai penjelas sebuah struktur program.
# 2. Bagian ketujuh sampai terakhir menghasilkan output.
# 3. program ini dijalankan dengan bahasa python.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang dapat digunakan untuk memahami dan menerapkan konsep dasar pemrograman. Penggunaan Visual Studio Code membantu dalam menulis dan menjalankan program, sedangkan GitHub digunakan untuk menyimpan serta mengelola kode program.
#
# Melalui praktikum ini, mahasiswa dapat memahami penggunaan dasar Python, VS Code, dan GitHub serta memperoleh pengalaman dalam membuat dan mengelola program secara lebih terstruktur.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Microsoft, "Visual Studio Code Documentation," [Online]. Tersedia: https://code.visualstudio.com/docs [Diakses 2026].
#
# [2] Python Software Foundation, "The Python Tutorial," [Online]. Tersedia: https://docs.python.org/3/tutorial/ [Diakses 2026].
#
# [3] GitHub, Inc., "Getting Started with GitHub," [Online]. Tersedia: https://docs.github.com/en/get-started [Diakses 2026].
